# %%
import pandas as pd

# %%
data = pd.read_csv("HW1-data.csv")

# %%
data.head()
# Out:
#    User  Gender (1 =F, 0=M)  260: Star Wars: Episode IV - A New Hope (1977)  \
# 0   755                   0                                             1.0
# 1  5277                   0                                             5.0
# 2  1577                   1                                             NaN
# 3  4388                   0                                             NaN
# 4  1202                   1                                             4.0
#
#    1210: Star Wars: Episode VI - Return of the Jedi (1983)  \
# 0                                                5.0
# 1                                                3.0
# 2                                                NaN
# 3                                                3.0
# 4                                                3.0
#
#    356: Forrest Gump (1994)  318: Shawshank Redemption, The (1994)  \
# 0                       2.0                                    NaN
# ...

# %%
data.mean()
# Out:
# User                                                       3658.100000
# Gender (1 =F, 0=M)                                            0.450000
# 260: Star Wars: Episode IV - A New Hope (1977)                3.266667
# 1210: Star Wars: Episode VI - Return of the Jedi (1983)       3.000000
# 356: Forrest Gump (1994)                                      2.700000
# 318: Shawshank Redemption, The (1994)                         3.600000
# 593: Silence of the Lambs, The (1991)                         3.062500
# 3578: Gladiator (2000)                                        2.916667
# 1: Toy Story (1995)                                           2.823529
# 2028: Saving Private Ryan (1998)                              3.000000
# 296: Pulp Fiction (1994)                                      3.000000
# 1259: Stand by Me (1986)                                      2.636364
# 2396: Shakespeare in Love (1998)                              2.909091
# ...

# %% [markdown]
# Mean Rating: Calculate the mean rating for each movie, order with
# the highest rating listed first, and
#
# submit the top three :
# 1. 318: Shawshank Redemption, The (1994)                         3.600000
# 2. 260: Star Wars: Episode IV - A New Hope (1977)                3.266667
# 3. 541: Blade Runner (1982)                                      3.222222
#
# (along with the mean scores for the top two).

# %%
data.count()
# Out:
# User                                                       20
# Gender (1 =F, 0=M)                                         20
# 260: Star Wars: Episode IV - A New Hope (1977)             15
# 1210: Star Wars: Episode VI - Return of the Jedi (1983)    14
# 356: Forrest Gump (1994)                                   10
# 318: Shawshank Redemption, The (1994)                      10
# 593: Silence of the Lambs, The (1991)                      16
# 3578: Gladiator (2000)                                     12
# 1: Toy Story (1995)                                        17
# 2028: Saving Private Ryan (1998)                           11
# 296: Pulp Fiction (1994)                                   11
# 1259: Stand by Me (1986)                                   11
# 2396: Shakespeare in Love (1998)                           11
# 2916: Total Recall (1990)                                  12
# 780: Independence Day (ID4) (1996)                         13
# ...

# %% [markdown]
# 1. 1: Toy Story (1995)                                        17
# 2. 593: Silence of the Lambs, The (1991)                      16
# 3. 260: Star Wars: Episode IV - A New Hope (1977)             15

# %%
df = data.drop(columns=['User','Gender (1 =F, 0=M)'])

# %%
rat4higher = df[df>3]

# %%
(rat4higher.count()/df.count())*100
# Out:
# 260: Star Wars: Episode IV - A New Hope (1977)             53.333333
# 1210: Star Wars: Episode VI - Return of the Jedi (1983)    35.714286
# 356: Forrest Gump (1994)                                   30.000000
# 318: Shawshank Redemption, The (1994)                      70.000000
# 593: Silence of the Lambs, The (1991)                      43.750000
# 3578: Gladiator (2000)                                     50.000000
# 1: Toy Story (1995)                                        35.294118
# 2028: Saving Private Ryan (1998)                           36.363636
# 296: Pulp Fiction (1994)                                   36.363636
# 1259: Stand by Me (1986)                                   36.363636
# 2396: Shakespeare in Love (1998)                           27.272727
# 2916: Total Recall (1990)                                   8.333333
# 780: Independence Day (ID4) (1996)                         30.769231
# 541: Blade Runner (1982)                                   44.444444
# ...

# %% [markdown]
# 1. 318: Shawshank Redemption, The (1994)                      70.000000
# 2. 260: Star Wars: Episode IV - A New Hope (1977)             53.333333
# 3. 3578: Gladiator (2000)                                     50.000000

# %%
df
# Out:
#     260: Star Wars: Episode IV - A New Hope (1977)  \
# 0                                              1.0
# 1                                              5.0
# 2                                              NaN
# 3                                              NaN
# 4                                              4.0
# 5                                              2.0
# 6                                              NaN
# 7                                              4.0
# 8                                              5.0
# 9                                              4.0
# 10                                             2.0
# 11                                             3.0
# 12                                             2.0
# 13                                             3.0
# 14                                             4.0
# 15                                             NaN
# 16                                             NaN
# ...
